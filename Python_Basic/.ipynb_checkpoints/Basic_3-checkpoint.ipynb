# %% [markdown]
# ## 1. Function
#
# ##### parameter & argument
# - 데이터를 넘길때 넘기는 데이터를 parameter라고 함
# - 데이터를 받을때 받는 데이터를 argument라고 함

# %%
def print_func(s1, s2="no_data"): # s2 : set basic parameter
    print("{} {}".format(s1, s2))
    
print_func("data_science")
print_func("wisconsin", "data_science") # position arguments
print_func(s2="data", s1="science") # keyword arguments
# Out:
# data_science no_data
# wisconsin data_science
# science data

# %%
def avg_func(korean, english, math):
    return (korean + english + math) / 3

# %%
a = avg_func(100, 70, 80)
print("avg : {}".format(round(a,2)))
# Out:
# avg : 83.33

# %% [markdown]
# ### *args
# - arguments
# - 함수에서 여러개의 파라미터를 한꺼번에 받을때 사용
# - 받는 arguments 데이터는 tuple 데이터 타입으로 받는다.
# - `*` 의 의미는 모든 value 를 받는다는 의미

# %%
def print_args(*args):
    print(args)
    print(type(args))
    print(args[4])
    print(args[5][1])
    
print_args(1, 2, 3, "slow", "kisd", ["data", "science"])
# Out:
# (1, 2, 3, 'slow', 'kisd', ['data', 'science'])
# <class 'tuple'>
# kisd
# science

# %%
def avg_func(*args):
    for data in args:
        print(data)
    return sum(args) / len(args)

a = avg_func(100, 70, 80)

print("avg : {}".format(round(a,2)))
# Out:
# 100
# 70
# 80
# avg : 83.33

# %% [markdown]
# ### **kwargs
# - keyword argument
# - 여러개의 파라미터를 key-value 형태로 받을때 사용
# - 함수에서 받는 keyword argument의 데이터는 dictionary 데이터 타입으로 받는다
# - `**` 의 의미는 모든 key, value를 받는 다는 의미
