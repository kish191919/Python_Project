# %%
a = 'hello world what a nice weather'
a.split("w")
# Out:
# ['hello ', 'orld ', 'hat a nice ', 'eather']

# %%
a = 'hello world'
a.replace('h', 'j')
# Out:
# 'jello world'

# %%
a.upper()
# Out:
# 'HELLO WORLD'

# %%
c, d =5, "a"
print(c,d)
# Out:
# 5 a

# %%
type(a)
# Out:
# str

# %%
a = "123456789"
a[::-1]
# Out:
# '987654321'

# %%
a[:], a[:len(a)]
# Out:
# ('123456789', '123456789')

# %%
# find() - 해당 문자열 위치 리턴 (없으면 -1 리턴)
print(a.find("3"))
print(a.find("10"))
# Out:
# 2
# -1

# %%
# index() - 해당 문자열 위치 리턴  (없으면 value error 리턴)
print(a.index("3"))
print(a.index("10"))
# Out:
# 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-2a6fdbb90f50> in <module>
#       1 # index() - 해당 문자열 위치 리턴  (없으면 value error 리턴)
#       2 print(a.index("3"))
# ----> 3 print(a.index("10"))
#
# ValueError: substring not found

# %%
a.count("1")
# Out:
# 1
