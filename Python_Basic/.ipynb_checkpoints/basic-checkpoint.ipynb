# %%
a = 'hello world what a nice weather'
a.split("w")
# Out:
# ['hello ', 'orld ', 'hat a nice ', 'eather']

# %%
a = 'hello world'
a.replace('h', 'j')
# Out:
# 'jello world'

# %%
a.upper()
# Out:
# 'HELLO WORLD'

# %%
c, d =5, "a"
print(c,d)
# Out:
# 5 a

# %%
type(a)
# Out:
# str

# %%
a = "123456789"
a[::-1]
# Out:
# '987654321'

# %%
a[:], a[:len(a)]
# Out:
# ('123456789', '123456789')
